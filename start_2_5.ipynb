# %%
import requests 
from urllib.parse import urlencode
import urllib3
import matplotlib.pyplot as plt
urllib3.disable_warnings()

# %%
# lon, lat =  37.61191755, 55.7965029
# param={"horizon":1,
#     'planchers_tot':56, # общее количество этажей
#     'height':179.9, # высота обхекта (м)
#     'souterrain':2, # количество подземных этажей
#     'planchers_sur':54, # количество надземных этажей
#     'n_app':450, # количество квартир
#     'superficie_tot':38910, # общая площадь объекта 
#     'espace_de_vie':22301.0, # жилая площадь объекта
#     'lon':lon, # долгота 
#     'lat':lat, # широта 
#        'park':1
# }

param={"horizon":1,
    'planchers_tot':25, # общее количество этажей
    'height':74.84, # высота объекта (м)
    'souterrain':2, # количество подземных этажей
    'planchers_sur':25, # количество надземных этажей
    'n_app':566, # количество квартир
    'superficie_tot':38025.85, # общая площадь объекта 
    'espace_de_vie':23802.6, # жилая площадь объекта
    'lon':37.443167, # долгота 
    'lat':55.624099, # широта 
       'park':0}

# param=dict(horizon=1.5,
# planchers_tot=13,
# height=45,
# souterrain=1 ,
# planchers_sur=12 ,
# n_app=320 ,
# superficie_tot=37808.7 , #Внутри Садового кольца
# espace_de_vie=17568.2 ,
# lon=37.640243,	
# lat=55.738715,
#           park=1)

url = 'http://127.0.0.1:5000/price?'+urlencode(param)
print(url)

r = requests.get(url, verify=False)
if r.status_code!=200:
    print('Failure', r.status_code)
print(r.text)
# Out:
# http://127.0.0.1:5000/price?horizon=1&planchers_tot=25&height=74.84&souterrain=2&planchers_sur=25&n_app=566&superficie_tot=38025.85&espace_de_vie=23802.6&lon=37.443167&lat=55.624099&park=0
# {
#   "center": 0,
#   "code": 0,
#   "csv_name": "results/prognose_2025-12-01_12-50-34.csv",
#   "dates": [
#     "2025-12-01",
#     "2026-03-01",
#     "2026-06-01",
#     "2026-08-01",
#     "2026-12-01",
#     "2027-03-01",
#     "2027-06-01",
#     "2027-08-01",
#     "2027-12-01"
#   ],
#   "excel_name": "results/prognose_2025-12-01_12-50-34.xlsx",
#   "forecast_horizon": [
#     0.0,
#     0.25,
#     0.5,
#     0.75,
#     1.0,
#     1.25,
#     1.5,
#     1.75,
#     2.0
#   ],
#   "lat": 55.624099,
#   "lon": 37.443167,
#   "official": [
#     1.0,
#     1.01,
#     1.022,
#     1.025,
#     1.045,
#     1.056,
#     1.068,
#     1.071,
#     1.091
#   ],
#   "parking": 0,
#   "price_index": [
#     1.0,
#     1.053,
#     1.085,
#     1.12,
#     1.152,
#     1.183,
#     1.214,
#     1.245,
#     1.274
#   ],
#   "pricemetr_dom": [
#     283.41,
#     298.49,
#     307.44,
#     317.53,
#     326.53,
#     335.31,
#     344.12,
#     352.81,
#     360.98
#   ],
#   "pricemetr_future_dom": 326.53,
#   "pricemetr_future_off": 296.09,
#   "pricemetr_off": [
#     283.41,
#     286.38,
#     289.61,
#     290.42,
#     296.09,
#     299.32,
#     302.56,
#     303.64,
#     309.3
#   ],
#   "pricemetr_today": 283.411,
#   "response": "Okay"
# }

# %%
res=eval(r.text)
plt.figure(figsize=(15,5))

plt.subplot(1,2,1)
plt.plot(res['forecast_horizon'], res['official'], label='Official', marker='o')
plt.plot(res['forecast_horizon'], res['price_index'], label='Domclick', marker='o')
plt.legend()
plt.grid()
plt.xlabel('Horizon')
plt.ylabel('Price index (based on 2025-07-01)')
plt.xticks(res['forecast_horizon'], res['dates'], rotation=60)

plt.subplot(1,2,2)
plt.plot(res['forecast_horizon'], res['pricemetr_off'], label='Official', marker='o', c='tab:green')
plt.plot(res['forecast_horizon'], res['pricemetr_dom'], label='Domclick', marker='o', c='tab:red')
plt.scatter(param["horizon"],res["pricemetr_future_dom"], marker='v',s=200, c='c', label='Forecast for a given horizon')
plt.scatter(param["horizon"],res["pricemetr_future_off"], marker='v',s=200, c='c' )
plt.legend()
plt.grid()
plt.xlabel('Horizon')
plt.ylabel('Price per sq. meter (thousand RUB) ')
plt.xticks(res['forecast_horizon'], res['dates'], rotation=60)
plt.tight_layout()
plt.savefig('index_plt.png')
plt.show()

# %%
lon, lat = 37.61191755, 55.7965029
param={
    'lon':lon, # долгота 
    'lat':lat, # широта 
    'year':2026, # прогнозируемый год
    'month':12, # прогнозируемый месяц
}
url= 'http://127.0.0.1:5000/demand?'+urlencode(param)
print(url)
r = requests.get(url, verify=False)
if r.status_code!=200:
    print('Failure', r.status_code)
eval(r.text)
# Out:
# http://127.0.0.1:5000/demand?lon=37.61191755&lat=55.7965029&year=2026&month=12
# {'1': 0.42,
#  '2': 0.35,
#  '3': 0.04,
#  '4': 0.19,
#  'code': 0,
#  'date': '2026-12-01',
#  'district': 'Марьина Роща',
#  'response': 'Okay'}
